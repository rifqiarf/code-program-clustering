# %%
# !pip install scikit-learn-extra
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage

sns.set()
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.26.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn-extra) (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.5.0)
# Downloading scikit_learn_extra-0.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.6 MB/s eta 0:00:00
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0

# %% [markdown]
# # KMEANS Pagi Program

# %%
df_merged = pd.read_csv("data_contoh_bab_2.csv", delimiter=";") # Data_merged_filtered_2, new_rush_hour_pagi
df_merged.head()
# Out:
#   corridor_name shelter_name  number_of_transaction
# 0     Koridor I      Halte A                     50
# 1     Koridor I      Halte B                     65
# 2     Koridor I      Halte C                     40
# 3     Koridor I      Halte D                     30
# 4     Koridor I      Halte E                     45

# %%
df_merged.dtypes
# Out:
# corridor_name            object
# shelter_name             object
# number_of_transaction     int64
# dtype: object

# %%
df_merged["corridor_name"].unique()
# Out:
# array(['Koridor I', 'Koridor II', 'Koridor III', 'Koridor IV'],
#       dtype=object)

# %% [markdown]
# ## Feature Engginering

# %%
label_encoder = LabelEncoder()
df_merged['corridor_name_encoded'] = label_encoder.fit_transform(df_merged['corridor_name'])

df_merged.sample(n=5, random_state=42)
# Out:
#    corridor_name shelter_name  number_of_transaction  corridor_name_encoded
# 0      Koridor I      Halte A                     50                      0
# 17    Koridor IV      Halte R                     35                      3
# 15    Koridor IV      Halte P                     45                      3
# 1      Koridor I      Halte B                     65                      0
# 8     Koridor II      Halte I                     35                      1

# %%
label_encoder.classes_
# Out:
# array(['Koridor I', 'Koridor II', 'Koridor III', 'Koridor IV'],
#       dtype=object)

# %%
df_merged['shelter_name'].unique()
# Out:
# array(['Halte A', 'Halte B', 'Halte C', 'Halte D', 'Halte E', 'Halte F',
#        'Halte G', 'Halte H', 'Halte I', 'Halte J', 'Halte K', 'Halte L',
#        'Halte M', 'Halte N', 'Halte O', 'Halte P', 'Halte Q', 'Halte R',
#        'Halte S', 'Halte T'], dtype=object)

# %%
# shelter_dummies = pd.get_dummies(df_merged['shelter_name_var'], prefix='shelter', drop_first=False)
# shelter_dummies = shelter_dummies.astype(int)

# df_merged = pd.concat([df_merged, shelter_dummies], axis=1)

# # label_encoder = LabelEncoder()
# # df_merged['shelter_name_encoded'] = label_encoder.fit_transform(df_merged['shelter_name_var'])

# df_merged.sample(n=10, random_state=42)

# %%
label_encoder = LabelEncoder()
df_merged['shelter_name_encoded'] = label_encoder.fit_transform(df_merged['shelter_name'])

df_merged.sample(n=10, random_state=42)
# Out:
#    corridor_name shelter_name  number_of_transaction  corridor_name_encoded  \
# 0      Koridor I      Halte A                     50                      0
# 17    Koridor IV      Halte R                     35                      3
# 15    Koridor IV      Halte P                     45                      3
# 1      Koridor I      Halte B                     65                      0
# 8     Koridor II      Halte I                     35                      1
# 5     Koridor II      Halte F                     55                      1
# 11   Koridor III      Halte L                     75                      2
# 3      Koridor I      Halte D                     30                      0
# 18    Koridor IV      Halte S                     25                      3
# 16    Koridor IV      Halte Q                     60                      3
#
#     shelter_name_encoded
# 0                      0
# 17                    17
# 15                    15
# 1                      1
# 8                      8
# 5                      5
# 11                    11
# 3                      3
# 18                    18
# 16                    16

# %%
# # Tidak sibuk dan Sore tidak di pakai dulu

# label_encoder_rush = LabelEncoder()
# df_merged['rush_hour_encoded'] = label_encoder_rush.fit_transform(df_merged['rush_hour'])

# df_merged_filtered = df_merged[df_merged['rush_hour_encoded'] != 2]
# df_merged_filtered = df_merged_filtered[df_merged_filtered['rush_hour_encoded'] != 1]

# df_merged_filtered.reset_index(drop=True, inplace=True)

# %%
# df_merged_filtered.sample(n=10, random_state=42)

# %%
df_merged.shape # df_merged
# Out:
# (20, 5)

# %% [markdown]
# ## Modeling

# %%
X = pd.concat([df_merged['shelter_name_encoded'].reset_index(drop=True), df_merged['number_of_transaction'].reset_index(drop=True)], axis=1)
X = X.sample(frac=1, random_state=42).reset_index(drop=True)

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X = pd.DataFrame(X_normalized, columns=X.columns)

X.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shelter_name_encoded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-735cd6dc05dd> in <cell line: 1>()
# ----> 1 X = pd.concat([df_merged['shelter_name_encoded'].reset_index(drop=True), df_merged['number_of_transaction'].reset_index(drop=True)], axis=1)
#       2 X = X.sample(frac=1, random_state=42).reset_index(drop=True)
#       3
#       4 scaler = MinMaxScaler()
#       5 X_normalized = scaler.fit_transform(X)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'shelter_name_encoded'

# %%
print(f"X Shape {X.shape}")
print(f"Full Features {df_merged.shape}")
# Out:
# X Shape (20, 2)
# Full Features (20, 5)

# %%
sse = []

# Coba k dari 1 sampai 10

k_values = range(1, 11)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# %%
print(sse)
# Out:
# [3.2916052631578947, 1.911924228433924, 1.1440535549399815, 0.7674903047091413, 0.6623439519852262, 0.5246315789473684, 0.3635734072022161, 0.27840027700831027, 0.21930517082179135, 0.17967913204062794]

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3 # 4

kmeans = KMeans(n_clusters=optimal_k, max_iter=10, random_state=42)
labels = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

X['cluster'] = labels
df_merged['cluster'] = labels

# df_merged_filtered['cluster'] = labels

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
        X['shelter_name_encoded'],
        X['number_of_transaction'],
          c=X['cluster'],
          cmap='viridis',
          alpha=0.6)

plt.scatter(centroids[:, 0],
          centroids[:, 1],
          c='red',
          marker="X",
          label="Centroids")

plt.xlabel('Jumlah Halte')
plt.ylabel('Jumlah Penumpang')

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
df_merged.head()
# Out:
#   corridor_name shelter_name  number_of_transaction  corridor_name_encoded  \
# 0     Koridor I      Halte A                     50                      0
# 1     Koridor I      Halte B                     65                      0
# 2     Koridor I      Halte C                     40                      0
# 3     Koridor I      Halte D                     30                      0
# 4     Koridor I      Halte E                     45                      0
#
#    shelter_name_encoded  cluster
# 0                     0        0
# 1                     1        2
# 2                     2        2
# 3                     3        1
# 4                     4        0

# %%
sse_final = kmeans.inertia_
silhouette_avg = silhouette_score(X, X['cluster'])
dbi = davies_bouldin_score(X, X['cluster'])

print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {df_merged.shape}")
# Out:
# SSE: 1.1440535549399815
# Silhouette Score: 0.7100688886874478
# Davies-Bouldin Index: 0.4062084982970256
# Data Index: (20, 6)

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen', 'gold'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

df_pca = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
df_pca['cluster'] = labels

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=50)
plt.title('PCA of Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
# Menyimpan data hasil clustering
df_merged = df_merged.drop(columns=['corridor_name_encoded', 'shelter_name_encoded'])
df_merged.to_csv("kmeans_pagi_result.csv", index=False)

# %% [markdown]
# # KMEANS Sore PROGRAM

# %%
df_merged = pd.read_csv("new_rush_hour_sore.csv") # Data_merged_filtered_2
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460

# %%
df_merged["corridor_name"].unique()
# Out:
# array(['BLOK M - KOTA', 'KALIDERES - PASAR BARU', 'LEBAK BULUS - HARMONI',
#        'PULOGADUNG 1 - HARMONI'], dtype=object)

# %% [markdown]
# ## Feature Engginering

# %%
label_encoder = LabelEncoder()
df_merged['corridor_name_encoded'] = label_encoder.fit_transform(df_merged['corridor_name'])

df_merged.sample(n=5, random_state=42)
# Out:
#              corridor_name         shelter_name  number_of_transaction  \
# 4            BLOK M - KOTA     BUNDARAN SENAYAN                 434460
# 63  PULOGADUNG 1 - HARMONI  PASAR CEMPAKA PUTIH                  39556
# 10           BLOK M - KOTA                 KOTA                 205466
# 0            BLOK M - KOTA                ASEAN                 107803
# 35   LEBAK BULUS - HARMONI          KEBON JERUK                 124462
#
#     corridor_name_encoded
# 4                       0
# 63                      3
# 10                      0
# 0                       0
# 35                      2

# %%
label_encoder.classes_
# Out:
# array(['BLOK M - KOTA', 'KALIDERES - PASAR BARU', 'LEBAK BULUS - HARMONI',
#        'PULOGADUNG 1 - HARMONI'], dtype=object)

# %%
df_merged['shelter_name'].unique()
# Out:
# array(['ASEAN', 'BENDUNGAN HILIR', 'BLOK M', 'BUNDARAN HI ASTRA',
#        'BUNDARAN SENAYAN', 'DUKUH ATAS', 'GLODOK', 'KARET',
#        'KEBON SIRIH ARAH KOTA', 'KEJAKSAAN AGUNG', 'KOTA',
#        'MANGGA BESAR ARAH KOTA', 'MASJID AGUNG', 'MH THAMRIN',
#        'MONUMEN NASIONAL', 'POLDA METRO JAYA', 'SENAYAN BANK DKI',
#        'TAMAN SARI', 'TELUK BETUNG', 'DAMAI', 'GROGOL', 'JELAMBAR',
#        'JEMBATAN BARU', 'JEMBATAN GANTUNG', 'KALIDERES', 'PASAR BARU',
#        'PESAKIH', 'PULO NANGKA', 'RAWA BUAYA', 'ROXY', 'SUMUR BOR',
#        'TAMAN KOTA', 'DURI KEPA', 'GROGOL II', 'KEBAYORAN LAMA BUNGUR',
#        'KEBON JERUK', 'KEDOYA ASSIDIQQIYAH', 'KEDOYA GREEN GARDEN',
#        'KELAPA DUA SASAK', 'LEBAK BULUS', 'PERMATA HIJAU',
#        'PERMATA HIJAU RS MEDIKA', 'PETOJO', 'PONDOK INDAH I',
#        'PONDOK INDAH II', 'PONDOK PINANG', 'POS PENGUMBEN',
#        'PS.KEBAYORAN LAMA', 'RS TARAKAN',
#        'S. PARMAN PODOMORO CITY ARAH PLUIT', 'SIMPRUG',
#        'TANAH KUSIR KODIM', 'TOMANG MANDALA', 'BALAI KOTA', 'BERMIS',
#        'CEMPAKA BARU', 'CEMPAKA MAS', 'GALUR', 'GAMBIR', 'GAMBIR 2',
#        'ISTIQLAL', 'JUANDA', 'KWITANG', 'PASAR CEMPAKA PUTIH',
#        'PASAR SENEN', 'PECENONGAN', 'PEDONGKELAN', 'PEJAMBON',
#        'PERINTIS KEMERDEKAAN', 'PULO GADUNG', 'PULO MAS', 'RAWA SELATAN',
#        'RSPAD', 'SENEN RAYA', 'SUMUR BATU'], dtype=object)

# %%
label_encoder = LabelEncoder()
df_merged['shelter_name_encoded'] = label_encoder.fit_transform(df_merged['shelter_name'])

df_merged.sample(n=10, random_state=42)
# Out:
#              corridor_name         shelter_name  number_of_transaction  \
# 4            BLOK M - KOTA     BUNDARAN SENAYAN                 434460
# 63  PULOGADUNG 1 - HARMONI  PASAR CEMPAKA PUTIH                  39556
# 10           BLOK M - KOTA                 KOTA                 205466
# 0            BLOK M - KOTA                ASEAN                 107803
# 35   LEBAK BULUS - HARMONI          KEBON JERUK                 124462
# 61  PULOGADUNG 1 - HARMONI               JUANDA                 282951
# 28  KALIDERES - PASAR BARU           RAWA BUAYA                 127477
# 12           BLOK M - KOTA         MASJID AGUNG                  95578
# 69  PULOGADUNG 1 - HARMONI          PULO GADUNG                 197357
# 64  PULOGADUNG 1 - HARMONI          PASAR SENEN                  73053
#
#     corridor_name_encoded  shelter_name_encoded
# 4                       0                     6
# 63                      3                    40
# 10                      0                    32
# 0                       0                     0
# 35                      2                    26
# 61                      3                    22
# 28                      1                    59
# 12                      0                    36
# 69                      3                    56
# 64                      3                    41

# %%
df_merged.shape
# Out:
# (75, 5)

# %% [markdown]
# ## Modeling

# %%
X = pd.concat([df_merged['shelter_name_encoded'].reset_index(drop=True), df_merged['number_of_transaction'].reset_index(drop=True)], axis=1)
X = X.sample(frac=1, random_state=42).reset_index(drop=True)

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X = pd.DataFrame(X_normalized, columns=X.columns)

X.head()
# Out:
#    shelter_name_encoded  number_of_transaction
# 0              0.081081               0.575139
# 1              0.540541               0.039015
# 2              0.432432               0.264256
# 3              0.000000               0.131668
# 4              0.351351               0.154284

# %%
sse = []

# Coba k dari 1 sampai 10

k_values = range(1, 11)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3 # 4

kmeans = KMeans(n_clusters=optimal_k, max_iter=10, random_state=42)
labels = kmeans.fit_predict(X)
centroids = kmeans.cluster_centers_

X['cluster'] = labels
df_merged['cluster'] = labels
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction  \
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460
#
#    corridor_name_encoded  shelter_name_encoded  cluster
# 0                      0                     0        0
# 1                      0                     2        1
# 2                      0                     4        2
# 3                      0                     5        2
# 4                      0                     6        2

# %%
sse_final = kmeans.inertia_
silhouette_avg = silhouette_score(X, X['cluster'])
dbi = davies_bouldin_score(X, X['cluster'])

print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {df_merged.shape}")
# Out:
# SSE: 2.9991765785445743
# Silhouette Score: 0.7867806414526395
# Davies-Bouldin Index: 0.35130120103957324
# Data Index: (75, 6)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
        X['shelter_name_encoded'],
        X['number_of_transaction'],
          c=X['cluster'],
          cmap='viridis',
          alpha=0.6)

plt.scatter(centroids[:, 0],
          centroids[:, 1],
          c='red',
          marker="X",
          label="Centroids")

plt.xlabel('Jumlah Halte')
plt.ylabel('Jumlah Penumpang')

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction  \
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460
#
#    corridor_name_encoded  shelter_name_encoded  cluster
# 0                      0                     0        0
# 1                      0                     2        1
# 2                      0                     4        2
# 3                      0                     5        2
# 4                      0                     6        2

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen', 'gold'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

df_pca = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
df_pca['cluster'] = labels

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=50)
plt.title('PCA of Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df_merged = df_merged.drop(columns=['corridor_name_encoded', 'shelter_name_encoded'])
df_merged.to_csv("kmeans_sore_result.csv", index=False)

# %% [markdown]
# # KMEDOITS PAGI PROGRAM

# %%
df_merged = pd.read_csv("data_contoh_bab_2.csv", delimiter=";") # Data_merged_filtered_2
df_merged.head()
# Out:
#   corridor_name shelter_name  number_of_transaction
# 0     Koridor I      Halte A                     50
# 1     Koridor I      Halte B                     65
# 2     Koridor I      Halte C                     40
# 3     Koridor I      Halte D                     30
# 4     Koridor I      Halte E                     45

# %%
df_merged["corridor_name"].unique()
# Out:
# array(['Koridor I', 'Koridor II', 'Koridor III', 'Koridor IV'],
#       dtype=object)

# %% [markdown]
# ## Feature Engginering

# %%
label_encoder = LabelEncoder()
df_merged['corridor_name_encoded'] = label_encoder.fit_transform(df_merged['corridor_name'])

df_merged.sample(n=5, random_state=42)
# Out:
#    corridor_name shelter_name  number_of_transaction  corridor_name_encoded
# 0      Koridor I      Halte A                     50                      0
# 17    Koridor IV      Halte R                     35                      3
# 15    Koridor IV      Halte P                     45                      3
# 1      Koridor I      Halte B                     65                      0
# 8     Koridor II      Halte I                     35                      1

# %%
label_encoder.classes_
# Out:
# array(['Koridor I', 'Koridor II', 'Koridor III', 'Koridor IV'],
#       dtype=object)

# %%
df_merged['shelter_name'].unique()
# Out:
# array(['Halte A', 'Halte B', 'Halte C', 'Halte D', 'Halte E', 'Halte F',
#        'Halte G', 'Halte H', 'Halte I', 'Halte J', 'Halte K', 'Halte L',
#        'Halte M', 'Halte N', 'Halte O', 'Halte P', 'Halte Q', 'Halte R',
#        'Halte S', 'Halte T'], dtype=object)

# %%
label_encoder = LabelEncoder()
df_merged['shelter_name_encoded'] = label_encoder.fit_transform(df_merged['shelter_name'])

df_merged.sample(n=10, random_state=42)
# Out:
#    corridor_name shelter_name  number_of_transaction  corridor_name_encoded  \
# 0      Koridor I      Halte A                     50                      0
# 17    Koridor IV      Halte R                     35                      3
# 15    Koridor IV      Halte P                     45                      3
# 1      Koridor I      Halte B                     65                      0
# 8     Koridor II      Halte I                     35                      1
# 5     Koridor II      Halte F                     55                      1
# 11   Koridor III      Halte L                     75                      2
# 3      Koridor I      Halte D                     30                      0
# 18    Koridor IV      Halte S                     25                      3
# 16    Koridor IV      Halte Q                     60                      3
#
#     shelter_name_encoded
# 0                      0
# 17                    17
# 15                    15
# 1                      1
# 8                      8
# 5                      5
# 11                    11
# 3                      3
# 18                    18
# 16                    16

# %%
df_merged.shape
# Out:
# (20, 5)

# %% [markdown]
# ## Modeling

# %%
X = pd.concat([df_merged['shelter_name_encoded'].reset_index(drop=True), df_merged['number_of_transaction'].reset_index(drop=True)], axis=1)
X = X.sample(frac=1, random_state=42).reset_index(drop=True)

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X = pd.DataFrame(X_normalized, columns=X.columns)

X.head()
# Out:
#    shelter_name_encoded  number_of_transaction
# 0              0.000000                    0.5
# 1              0.894737                    0.2
# 2              0.789474                    0.4
# 3              0.052632                    0.8
# 4              0.421053                    0.2

# %%
sse = []

# Coba k dari 1 sampai 10

k_values = range(1, 11)
for k in k_values:
    kmedoids = KMedoids(n_clusters=k, random_state=42)
    kmedoids.fit(X)
    sse.append(kmedoids.inertia_)

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3 # 4

kmedoids = KMedoids(n_clusters=optimal_k, max_iter=10, random_state=42)
labels = kmedoids.fit_predict(X)
centroids = kmedoids.cluster_centers_

X['cluster'] = labels
df_merged['cluster'] = labels

# %%
df_merged.head()
# Out:
#   corridor_name shelter_name  number_of_transaction  cluster
# 0     Koridor I      Halte A                     50        0
# 1     Koridor I      Halte B                     65        1
# 2     Koridor I      Halte C                     40        1
# 3     Koridor I      Halte D                     30        0
# 4     Koridor I      Halte E                     45        1

# %%
sse_final = kmedoids.inertia_
silhouette_avg = silhouette_score(X, X['cluster'])
dbi = davies_bouldin_score(X, X['cluster'])

print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {df_merged.shape}")
# Out:
# SSE: 4.412500409745561
# Silhouette Score: 0.7143599724272138
# Davies-Bouldin Index: 0.3878020406594311
# Data Index: (20, 6)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
        X['shelter_name_encoded'],
        X['number_of_transaction'],
          c=X['cluster'],
          cmap='viridis',
          alpha=0.6)

plt.scatter(centroids[:, 0],
          centroids[:, 1],
          c='red',
          marker="X",
          label="Centroids")

plt.xlabel('Jumlah Halte')
plt.ylabel('Jumlah Penumpang')

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
df_merged.head()
# Out:
#   corridor_name shelter_name  number_of_transaction  corridor_name_encoded  \
# 0     Koridor I      Halte A                     50                      0
# 1     Koridor I      Halte B                     65                      0
# 2     Koridor I      Halte C                     40                      0
# 3     Koridor I      Halte D                     30                      0
# 4     Koridor I      Halte E                     45                      0
#
#    shelter_name_encoded  cluster
# 0                     0        0
# 1                     1        1
# 2                     2        1
# 3                     3        0
# 4                     4        1

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen', 'gold', 'brown'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

df_pca = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
df_pca['cluster'] = labels

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=50)
plt.title('PCA of Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
df_merged = df_merged.drop(columns=['corridor_name_encoded', 'shelter_name_encoded'])
df_merged.to_csv("kmedoids_pagi_result.csv", index=False)

# %% [markdown]
# # KMEDOITS SORE PROGRAM

# %%
df_merged = pd.read_csv("new_rush_hour_sore.csv") # Data_merged_filtered_2
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460

# %% [markdown]
# ## Feature Engginering

# %%
label_encoder = LabelEncoder()
df_merged['corridor_name_encoded'] = label_encoder.fit_transform(df_merged['corridor_name'])

df_merged.sample(n=5, random_state=42)
# Out:
#              corridor_name         shelter_name  number_of_transaction  \
# 4            BLOK M - KOTA     BUNDARAN SENAYAN                 434460
# 63  PULOGADUNG 1 - HARMONI  PASAR CEMPAKA PUTIH                  39556
# 10           BLOK M - KOTA                 KOTA                 205466
# 0            BLOK M - KOTA                ASEAN                 107803
# 35   LEBAK BULUS - HARMONI          KEBON JERUK                 124462
#
#     corridor_name_encoded
# 4                       0
# 63                      3
# 10                      0
# 0                       0
# 35                      2

# %%
label_encoder.classes_
# Out:
# array(['BLOK M - KOTA', 'KALIDERES - PASAR BARU', 'LEBAK BULUS - HARMONI',
#        'PULOGADUNG 1 - HARMONI'], dtype=object)

# %%
df_merged['shelter_name'].unique()
# Out:
# array(['ASEAN', 'BENDUNGAN HILIR', 'BLOK M', 'BUNDARAN HI ASTRA',
#        'BUNDARAN SENAYAN', 'DUKUH ATAS', 'GLODOK', 'KARET',
#        'KEBON SIRIH ARAH KOTA', 'KEJAKSAAN AGUNG', 'KOTA',
#        'MANGGA BESAR ARAH KOTA', 'MASJID AGUNG', 'MH THAMRIN',
#        'MONUMEN NASIONAL', 'POLDA METRO JAYA', 'SENAYAN BANK DKI',
#        'TAMAN SARI', 'TELUK BETUNG', 'DAMAI', 'GROGOL', 'JELAMBAR',
#        'JEMBATAN BARU', 'JEMBATAN GANTUNG', 'KALIDERES', 'PASAR BARU',
#        'PESAKIH', 'PULO NANGKA', 'RAWA BUAYA', 'ROXY', 'SUMUR BOR',
#        'TAMAN KOTA', 'DURI KEPA', 'GROGOL II', 'KEBAYORAN LAMA BUNGUR',
#        'KEBON JERUK', 'KEDOYA ASSIDIQQIYAH', 'KEDOYA GREEN GARDEN',
#        'KELAPA DUA SASAK', 'LEBAK BULUS', 'PERMATA HIJAU',
#        'PERMATA HIJAU RS MEDIKA', 'PETOJO', 'PONDOK INDAH I',
#        'PONDOK INDAH II', 'PONDOK PINANG', 'POS PENGUMBEN',
#        'PS.KEBAYORAN LAMA', 'RS TARAKAN',
#        'S. PARMAN PODOMORO CITY ARAH PLUIT', 'SIMPRUG',
#        'TANAH KUSIR KODIM', 'TOMANG MANDALA', 'BALAI KOTA', 'BERMIS',
#        'CEMPAKA BARU', 'CEMPAKA MAS', 'GALUR', 'GAMBIR', 'GAMBIR 2',
#        'ISTIQLAL', 'JUANDA', 'KWITANG', 'PASAR CEMPAKA PUTIH',
#        'PASAR SENEN', 'PECENONGAN', 'PEDONGKELAN', 'PEJAMBON',
#        'PERINTIS KEMERDEKAAN', 'PULO GADUNG', 'PULO MAS', 'RAWA SELATAN',
#        'RSPAD', 'SENEN RAYA', 'SUMUR BATU'], dtype=object)

# %%
label_encoder = LabelEncoder()
df_merged['shelter_name_encoded'] = label_encoder.fit_transform(df_merged['shelter_name'])

df_merged.sample(n=10, random_state=42)
# Out:
#              corridor_name         shelter_name  number_of_transaction  \
# 4            BLOK M - KOTA     BUNDARAN SENAYAN                 434460
# 63  PULOGADUNG 1 - HARMONI  PASAR CEMPAKA PUTIH                  39556
# 10           BLOK M - KOTA                 KOTA                 205466
# 0            BLOK M - KOTA                ASEAN                 107803
# 35   LEBAK BULUS - HARMONI          KEBON JERUK                 124462
# 61  PULOGADUNG 1 - HARMONI               JUANDA                 282951
# 28  KALIDERES - PASAR BARU           RAWA BUAYA                 127477
# 12           BLOK M - KOTA         MASJID AGUNG                  95578
# 69  PULOGADUNG 1 - HARMONI          PULO GADUNG                 197357
# 64  PULOGADUNG 1 - HARMONI          PASAR SENEN                  73053
#
#     corridor_name_encoded  shelter_name_encoded
# 4                       0                     6
# 63                      3                    40
# 10                      0                    32
# 0                       0                     0
# 35                      2                    26
# 61                      3                    22
# 28                      1                    59
# 12                      0                    36
# 69                      3                    56
# 64                      3                    41

# %%
df_merged.shape
# Out:
# (75, 5)

# %% [markdown]
# ## Modeling

# %%
X = pd.concat([df_merged['shelter_name_encoded'].reset_index(drop=True), df_merged['number_of_transaction'].reset_index(drop=True)], axis=1)
X = X.sample(frac=1, random_state=42).reset_index(drop=True)

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X = pd.DataFrame(X_normalized, columns=X.columns)

X.head()
# Out:
#    shelter_name_encoded  number_of_transaction
# 0              0.081081               0.575139
# 1              0.540541               0.039015
# 2              0.432432               0.264256
# 3              0.000000               0.131668
# 4              0.351351               0.154284

# %%
sse = []

# Coba k dari 1 sampai 10

k_values = range(1, 11)
for k in k_values:
    kmedoids = KMedoids(n_clusters=k, random_state=42)
    kmedoids.fit(X)
    sse.append(kmedoids.inertia_)

# %%
print(sse)
# Out:
# [22.967925195223273, 14.956651139206102, 12.474586333176969, 10.694271484119586, 10.258256820464466, 8.843141540760179, 8.563096132354827, 8.374702361784752, 8.199179841182879, 7.761010897551474]

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3 # 4

kmedoids = KMedoids(n_clusters=optimal_k, max_iter=10, random_state=42)
labels = kmedoids.fit_predict(X)
centroids = kmedoids.cluster_centers_

X['cluster'] = labels
df_merged['cluster'] = labels

# %%
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction  \
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460
#
#    corridor_name_encoded  shelter_name_encoded  cluster
# 0                      0                     0        2
# 1                      0                     2        1
# 2                      0                     4        1
# 3                      0                     5        2
# 4                      0                     6        1

# %%
sse_final = kmedoids.inertia_
silhouette_avg = silhouette_score(X, X['cluster'])
dbi = davies_bouldin_score(X, X['cluster'])

print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {df_merged.shape}")
# Out:
# SSE: 12.474586333176969
# Silhouette Score: 0.7781267263375853
# Davies-Bouldin Index: 0.3127877073813639
# Data Index: (75, 6)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
        X['shelter_name_encoded'],
        X['number_of_transaction'],
          c=X['cluster'],
          cmap='viridis',
          alpha=0.6)

plt.scatter(centroids[:, 0],
          centroids[:, 1],
          c='red',
          marker="X",
          label="Centroids")

plt.xlabel('Jumlah Halte')
plt.ylabel('Jumlah Penumpang')

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
df_merged.head()
# Out:
#    corridor_name       shelter_name  number_of_transaction  \
# 0  BLOK M - KOTA              ASEAN                 107803
# 1  BLOK M - KOTA    BENDUNGAN HILIR                  41520
# 2  BLOK M - KOTA             BLOK M                 357745
# 3  BLOK M - KOTA  BUNDARAN HI ASTRA                 488951
# 4  BLOK M - KOTA   BUNDARAN SENAYAN                 434460
#
#    corridor_name_encoded  shelter_name_encoded  cluster
# 0                      0                     0        2
# 1                      0                     2        1
# 2                      0                     4        1
# 3                      0                     5        2
# 4                      0                     6        1

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'lightgreen', 'gold', 'brown'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

df_pca = pd.DataFrame(data=X_pca, columns=['PCA1', 'PCA2'])
df_pca['cluster'] = labels

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='cluster', palette='viridis', s=50)
plt.title('PCA of Clustering Results')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title='Cluster')
plt.show()
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Raqwan\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df_merged = df_merged.drop(columns=['corridor_name_encoded', 'shelter_name_encoded'])
df_merged.to_csv("kmedoids_sore_result.csv", index=False)

# %%
# Note Cell di bawah abaikan saja

# %% [markdown]
# # Filter Data 1

# %%
data = pd.read_csv("Data_1.csv")

# %%
data.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0        2023/12/1     BLOK M - KOTA            BLOK M         0
# 1        2023/12/1     BLOK M - KOTA      MASJID AGUNG         0
# 2        2023/12/1     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3        2023/12/1     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4        2023/12/1     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int
# 0                        30
# 1                         1
# 2                         4
# 3                        18
# 4                        15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134141 entries, 0 to 134140
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   transaction_date          134141 non-null  object
#  1   corridor_name_var         134141 non-null  object
#  2   shelter_name_var          134141 non-null  object
#  3   hour_int                  134141 non-null  int64
#  4   count_of_transaction_int  134141 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 5.1+ MB

# %%
data['transaction_date'] = pd.to_datetime(data['transaction_date'])

data.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0       2023-12-01     BLOK M - KOTA            BLOK M         0
# 1       2023-12-01     BLOK M - KOTA      MASJID AGUNG         0
# 2       2023-12-01     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3       2023-12-01     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4       2023-12-01     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int
# 0                        30
# 1                         1
# 2                         4
# 3                        18
# 4                        15

# %%
data.shape
# Out:
# (134141, 5)

# %%
df_weekdays = data[data['transaction_date'].dt.weekday < 5]

df_weekdays.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0       2023-12-01     BLOK M - KOTA            BLOK M         0
# 1       2023-12-01     BLOK M - KOTA      MASJID AGUNG         0
# 2       2023-12-01     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3       2023-12-01     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4       2023-12-01     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int
# 0                        30
# 1                         1
# 2                         4
# 3                        18
# 4                        15

# %%
df_weekdays.info(), df_weekdays.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95520 entries, 0 to 133626
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   transaction_date          95520 non-null  datetime64[ns]
#  1   corridor_name_var         95520 non-null  object
#  2   shelter_name_var          95520 non-null  object
#  3   hour_int                  95520 non-null  int64
#  4   count_of_transaction_int  95520 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 4.4+ MB
# (None, (95520, 5))

# %%
df_weekdays = df_weekdays[~df_weekdays['shelter_name_var'].str.contains("ARAH BLOK M", case=False, na=False)]

# %%
df_weekdays.shape
# Out:
# (82178, 5)

# %%
df_weekdays.head(15)
# Out:
#    transaction_date corridor_name_var       shelter_name_var  hour_int  \
# 0        2023-12-01     BLOK M - KOTA                 BLOK M         0
# 1        2023-12-01     BLOK M - KOTA           MASJID AGUNG         0
# 2        2023-12-01     BLOK M - KOTA       BUNDARAN SENAYAN         0
# 3        2023-12-01     BLOK M - KOTA       SENAYAN BANK DKI         0
# 4        2023-12-01     BLOK M - KOTA       POLDA METRO JAYA         0
# 5        2023-12-01     BLOK M - KOTA                  KARET         0
# 6        2023-12-01     BLOK M - KOTA             DUKUH ATAS         0
# 7        2023-12-01     BLOK M - KOTA           TELUK BETUNG         0
# 8        2023-12-01     BLOK M - KOTA      BUNDARAN HI ASTRA         0
# 9        2023-12-01     BLOK M - KOTA       MONUMEN NASIONAL         0
# 10       2023-12-01     BLOK M - KOTA             TAMAN SARI         0
# 11       2023-12-01     BLOK M - KOTA                   KOTA         0
# 13       2023-12-01     BLOK M - KOTA  KEBON SIRIH ARAH KOTA         0
# 14       2023-12-01     BLOK M - KOTA        KEJAKSAAN AGUNG         0
# 15       2023-12-01     BLOK M - KOTA                  ASEAN         0
#
#     count_of_transaction_int
# 0                         30
# 1                          1
# 2                          4
# 3                         18
# 4                         15
# 5                         14
# 6                          3
# 7                          7
# 8                         13
# 9                          9
# 10                         5
# 11                        18
# 13                         7
# 14                         4
# 15                        18

# %%
df_weekdays.to_csv("Data_1_filtered.csv", index=False)

# %% [markdown]
# # Filter Data 2

# %%
data = pd.read_csv("Data_2.csv")

# %%
data.head()
# Out:
#   transaction_date       corridor_name_var shelter_name_var  hour_int  \
# 0        1/12/2023  KALIDERES - PASAR BARU           GROGOL         0
# 1        1/12/2023  KALIDERES - PASAR BARU           GROGOL         1
# 2        1/12/2023  KALIDERES - PASAR BARU           GROGOL         4
# 3        1/12/2023  KALIDERES - PASAR BARU           GROGOL         5
# 4        1/12/2023  KALIDERES - PASAR BARU           GROGOL         6
#
#    count_of_transaction_int
# 0                         1
# 1                         1
# 2                         2
# 3                        21
# 4                       129

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333885 entries, 0 to 333884
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   transaction_date          333885 non-null  object
#  1   corridor_name_var         333885 non-null  object
#  2   shelter_name_var          333885 non-null  object
#  3   hour_int                  333885 non-null  int64
#  4   count_of_transaction_int  333885 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 12.7+ MB

# %%
data['transaction_date'] = pd.to_datetime(data['transaction_date'], errors='coerce', dayfirst=True)

data['transaction_date'] = data['transaction_date'].dt.strftime('%Y-%m-%d')

df_weekdays = data[data['transaction_date'].apply(lambda x: pd.Timestamp(x).weekday() < 5)]

df_weekdays.head()
# Out:
#   transaction_date       corridor_name_var shelter_name_var  hour_int  \
# 0       2023-12-01  KALIDERES - PASAR BARU           GROGOL         0
# 1       2023-12-01  KALIDERES - PASAR BARU           GROGOL         1
# 2       2023-12-01  KALIDERES - PASAR BARU           GROGOL         4
# 3       2023-12-01  KALIDERES - PASAR BARU           GROGOL         5
# 4       2023-12-01  KALIDERES - PASAR BARU           GROGOL         6
#
#    count_of_transaction_int
# 0                         1
# 1                         1
# 2                         2
# 3                        21
# 4                       129

# %%
df_weekdays.info(), df_weekdays.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 237604 entries, 0 to 332614
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   transaction_date          237604 non-null  object
#  1   corridor_name_var         237604 non-null  object
#  2   shelter_name_var          237604 non-null  object
#  3   hour_int                  237604 non-null  int64
#  4   count_of_transaction_int  237604 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 10.9+ MB
# (None, (237604, 5))

# %%
df_weekdays = df_weekdays[~df_weekdays['shelter_name_var'].str.contains("ARAH P.RANTI", case=False, na=False)]

# %%
df_weekdays.shape
# Out:
# (233038, 5)

# %%
df_weekdays.to_csv("Data_2_filtered.csv", index=False)

# %% [markdown]
# # Merging Data & Create Rush Our

# %%
df1 = pd.read_csv("Data_1_filtered.csv")
df2 = pd.read_csv("Data_2_filtered.csv")

df_merged = pd.concat([df1, df2], ignore_index=True)

# %%
df_merged.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0       2023-12-01     BLOK M - KOTA            BLOK M         0
# 1       2023-12-01     BLOK M - KOTA      MASJID AGUNG         0
# 2       2023-12-01     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3       2023-12-01     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4       2023-12-01     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int
# 0                        30
# 1                         1
# 2                         4
# 3                        18
# 4                        15

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315216 entries, 0 to 315215
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   transaction_date          315216 non-null  object
#  1   corridor_name_var         315216 non-null  object
#  2   shelter_name_var          315216 non-null  object
#  3   hour_int                  315216 non-null  int64
#  4   count_of_transaction_int  315216 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 12.0+ MB

# %%
df_merged.to_csv("Data_merged_filtered.csv", index=False)

# %%
df = pd.read_csv("Data_merged_filtered.csv")

df.shape
# Out:
# (315216, 5)

# %%
df.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0       2023-12-01     BLOK M - KOTA            BLOK M         0
# 1       2023-12-01     BLOK M - KOTA      MASJID AGUNG         0
# 2       2023-12-01     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3       2023-12-01     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4       2023-12-01     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int
# 0                        30
# 1                         1
# 2                         4
# 3                        18
# 4                        15

# %%
df['rush_hour'] = np.where(df['hour_int'].between(5, 9), 'pagi',
                                   np.where(df['hour_int'].between(16, 20), 'sore', 'tidak sibuk'))

# %%
df.head()
# Out:
#   transaction_date corridor_name_var  shelter_name_var  hour_int  \
# 0       2023-12-01     BLOK M - KOTA            BLOK M         0
# 1       2023-12-01     BLOK M - KOTA      MASJID AGUNG         0
# 2       2023-12-01     BLOK M - KOTA  BUNDARAN SENAYAN         0
# 3       2023-12-01     BLOK M - KOTA  SENAYAN BANK DKI         0
# 4       2023-12-01     BLOK M - KOTA  POLDA METRO JAYA         0
#
#    count_of_transaction_int    rush_hour
# 0                        30  tidak sibuk
# 1                         1  tidak sibuk
# 2                         4  tidak sibuk
# 3                        18  tidak sibuk
# 4                        15  tidak sibuk

# %%
df.shape
# Out:
# (315216, 6)

# %%
df.to_csv("Data_merged_filtered_2.csv", index=False)

# %% [markdown]
# # New Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.decomposition import PCA
from scipy.cluster.hierarchy import dendrogram, linkage

sns.set()

# %% [markdown]
# # KMEANS

# %%
df_merged = pd.read_csv("rush_hour_sore.csv")
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte
# 0               12.9            17
# 1               24.2            12
# 2               19.0            20
# 3               16.0            22

# %%
label_encoder = LabelEncoder()
df_merged['koridor_encoded'] = label_encoder.fit_transform(df_merged['Koridor'])

# %%
X = df_merged.copy()
X = X.iloc[:, 1:]
X.head()
# Out:
#    Total Penumpang (Rush Hour Sore)  Panjang Rute (km)  Jumlah Halte  \
# 0                           6860060               12.9            17
# 1                           1874288               24.2            12
# 2                           3360266               19.0            20
# 3                           2623212               16.0            22
#
#    koridor_encoded
# 0                0
# 1                1
# 2                2
# 3                3

# %%
sse = []

# Coba k dari 1 sampai 10

k_values = range(1, 5)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
print(sse)
# Out:
# [14592406956806.2, 1104088791151.0933, 271624299465.0, 0.0]

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(X)
df_merged['cluster'] = kmeans.labels_
# Out:
# C:\Users\Raqwan\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte  koridor_encoded  cluster
# 0               12.9            17                0        1
# 1               24.2            12                1        0
# 2               19.0            20                2        2
# 3               16.0            22                3        2

# %%
sse_final = kmeans.inertia_
silhouette_avg = silhouette_score(X, df_merged['cluster'])
dbi = davies_bouldin_score(X, df_merged['cluster'])

# Tampilkan hasil evaluasi
print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {df_merged_filtered.shape}")
# Out:
# SSE: 271624299465.0
# Silhouette Score: 0.1299608520061511
# Davies-Bouldin Index: 0.2516176735009634
# Data Index: (141931, 83)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_merged['Total Penumpang (Rush Hour Sore)'],
                      df_merged['Jumlah Halte'],
                      c=df_merged['cluster'],
                      cmap='rainbow',
                      alpha=0.6)

plt.xlabel('Total Penumpang (Rush Hour Pagi)')
plt.ylabel('Jumlah Halte')

plt.xlim(-10, 7263116)
plt.ylim(-10, 30)

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
df_merged = df_merged.drop(columns=['koridor_encoded'])
df_merged.to_csv("kmeans_cluster_pagi.csv", index=False)

# %% [markdown]
# # KMEDOIDS

# %%
df_merged = pd.read_csv("rush_hour_sore.csv")
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte
# 0               12.9            17
# 1               24.2            12
# 2               19.0            20
# 3               16.0            22

# %%
label_encoder = LabelEncoder()
df_merged['koridor_encoded'] = label_encoder.fit_transform(df_merged['Koridor'])

# %%
X = df_merged.copy()
X = X.iloc[:, 1:]
X.head()
# Out:
#    Total Penumpang (Rush Hour Sore)  Panjang Rute (km)  Jumlah Halte  \
# 0                           6860060               12.9            17
# 1                           1874288               24.2            12
# 2                           3360266               19.0            20
# 3                           2623212               16.0            22
#
#    koridor_encoded
# 0                0
# 1                1
# 2                2
# 3                3

# %%
sse = []

k_values = range(1, 5)
for k in k_values:
    kmedoids = KMedoids(n_clusters=k, random_state=42)
    kmedoids.fit(X)
    sse.append(kmedoids.inertia_)

# %%
print(sse)
# Out:
# [5722826.000047639, 4236848.00001667, 3499794.000007172, 0.0]

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3

kmedoids = KMedoids(n_clusters=optimal_k, random_state=42)
kmedoids.fit(X)
df_merged['cluster'] = kmedoids.labels_

# %%
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte  koridor_encoded  cluster
# 0               12.9            17                0        0
# 1               24.2            12                1        2
# 2               19.0            20                2        0
# 3               16.0            22                3        1

# %%
sse_final = kmedoids.inertia_
silhouette_avg = silhouette_score(X, df_merged['cluster'])
dbi = davies_bouldin_score(X, df_merged['cluster'])

# Tampilkan hasil evaluasi
print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {X.shape}")
# Out:
# SSE: 3499794.000007172
# Silhouette Score: -0.15385948342996586
# Davies-Bouldin Index: 0.6493477032057797
# Data Index: (4, 4)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_merged['Total Penumpang (Rush Hour Sore)'],
                      df_merged['Jumlah Halte'],
                      c=df_merged['cluster'],
                      cmap='rainbow',
                      alpha=0.6)

plt.xlabel('Total Penumpang (Rush Hour Pagi)')
plt.ylabel('Jumlah Halte')

plt.xlim(-10, 7263116)
plt.ylim(-10, 30)

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
df_merged = df_merged.drop(columns=['koridor_encoded'])
df_merged.to_csv("kmedoids_cluster_pagi.csv", index=False)

# %% [markdown]
# # KMEDOIDS Normalisasi

# %%
df_merged = pd.read_csv("rush_hour_sore.csv")
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte
# 0               12.9            17
# 1               24.2            12
# 2               19.0            20
# 3               16.0            22

# %%
label_encoder = LabelEncoder()
df_merged['koridor_encoded'] = label_encoder.fit_transform(df_merged['Koridor'])

# %%
X = df_merged.copy()
X = X.iloc[:, 1:]
X.head()
# Out:
#    Total Penumpang (Rush Hour Sore)  Panjang Rute (km)  Jumlah Halte  \
# 0                           6860060               12.9            17
# 1                           1874288               24.2            12
# 2                           3360266               19.0            20
# 3                           2623212               16.0            22
#
#    koridor_encoded
# 0                0
# 1                1
# 2                2
# 3                3

# %%
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

X = pd.DataFrame(X_normalized, columns=X.columns)
X.head()
# Out:
#    Total Penumpang (Rush Hour Sore)  Panjang Rute (km)  Jumlah Halte  \
# 0                          1.000000           0.000000           0.5
# 1                          0.000000           1.000000           0.0
# 2                          0.298044           0.539823           0.8
# 3                          0.150212           0.274336           1.0
#
#    koridor_encoded
# 0         0.000000
# 1         0.333333
# 2         0.666667
# 3         1.000000

# %%
sse = []

k_values = range(1, 5)
for k in k_values:
    kmedoids = KMedoids(n_clusters=k, random_state=42)
    kmedoids.fit(X)
    sse.append(kmedoids.inertia_)

# %%
print(sse)
# Out:
# [2.6672325161481063, 2.1738275547734665, 1.1483013341103283, 0.0]

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, sse, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
optimal_k = 3

kmedoids = KMedoids(n_clusters=optimal_k, random_state=42)
kmedoids.fit(X)
df_merged['cluster'] = kmedoids.labels_

# %%
df_merged.head()
# Out:
#                   Koridor  Total Penumpang (Rush Hour Sore)  \
# 0           BLOK M - KOTA                           6860060
# 1  KALIDERES - PASAR BARU                           1874288
# 2   LEBAK BULUS - HARMONI                           3360266
# 3  PULOGADUNG 1 - HARMONI                           2623212
#
#    Panjang Rute (km)  Jumlah Halte  koridor_encoded  cluster
# 0               12.9            17                0        0
# 1               24.2            12                1        2
# 2               19.0            20                2        0
# 3               16.0            22                3        1

# %%
sse_final = kmedoids.inertia_
silhouette_avg = silhouette_score(X, df_merged['cluster'])
dbi = davies_bouldin_score(X, df_merged['cluster'])

# Tampilkan hasil evaluasi
print(f"SSE: {sse_final}")
print(f"Silhouette Score: {silhouette_avg}")
print(f"Davies-Bouldin Index: {dbi}")
print(f"Data Index: {X.shape}")
# Out:
# SSE: 1.1483013341103283
# Silhouette Score: -0.09320877794794868
# Davies-Bouldin Index: 0.5868969043883258
# Data Index: (4, 4)

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_merged['Total Penumpang (Rush Hour Sore)'],
                      df_merged['Jumlah Halte'],
                      c=df_merged['cluster'],
                      cmap='rainbow',
                      alpha=0.6)

plt.xlabel('Total Penumpang (Rush Hour Pagi)')
plt.ylabel('Jumlah Halte')

plt.xlim(-10, 7263116)
plt.ylim(-10, 30)

cbar = plt.colorbar(scatter)
cbar.set_label('Cluster Label')

plt.title("Scatter Plot Clustering Result")
plt.show()

# %%
plt.figure(figsize=(6, 4))
df_merged['cluster'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Distribusi Cluster')
plt.xlabel('Cluster')
plt.ylabel('Jumlah Sampel')
plt.xticks(rotation=0)
plt.show()

# %%
df_merged = df_merged.drop(columns=['koridor_encoded'])
df_merged.to_csv("kmedoids_normalisasi_cluster_pagi.csv", index=False)
